# %%
# read /home/mcheung1/Ringdown/jaxqualin/Jaxqualin/CCE_waveforms/CCE_processed/0001_hdict_radext_292_Lev_5.h
# and plot the waveform

import numpy as np
import matplotlib.pyplot as plt
import h5py
import os

# %%
# read /home/mcheung1/Ringdown/jaxqualin/Jaxqualin/CCE_waveforms/CCE_processed/0001_hdict_radext_292_Lev_5.h

h5file = h5py.File('/home/mcheung1/Ringdown/jaxqualin/Jaxqualin/CCE_waveforms/CCE_processed/0001_hdict_radext_292_Lev_5.h', 'r')

# %%
list(h5file.keys())
# Out:
# ['Lev', 'Mf', 'af', 'hdict']

# %%
h22 = h5file['hdict']['2,2'][()]

# %%
list(h5file['hdict'].keys())
# Out:
# ['2,-1',
#  '2,-2',
#  '2,0',
#  '2,1',
#  '2,2',
#  '3,-1',
#  '3,-2',
#  '3,-3',
#  '3,0',
#  '3,1',
#  '3,2',
#  '3,3',
#  '4,-1',
#  '4,-2',
#  '4,-3',
#  '4,-4',
#  '4,0',
#  '4,1',
#  '4,2',
#  '4,3',
#  '4,4',
#  '5,-1',
#  '5,-2',
#  '5,-3',
#  '5,-4',
#  '5,-5',
#  '5,0',
#  '5,1',
#  '5,2',
#  '5,3',
#  '5,4',
#  '5,5',
#  '6,-1',
#  '6,-2',
#  '6,-3',
#  '6,-4',
#  '6,-5',
#  '6,-6',
#  '6,0',
#  '6,1',
#  '6,2',
#  '6,3',
#  '6,4',
#  '6,5',
#  '6,6']

# %%
plt.plot(h22[2])
